# %% [markdown]
# # COIN 2021 Orientation

# %% [markdown]
# ## COIN 2021 운영 계획

# %% [markdown]
# ### 1주차

# %% [markdown]
#    - Python 기본 타입 및 변수의 이해
#    - Python 문자열 타입의 이해 및 활용

# %% [markdown]
# ### 2주차
#    - Python 컬렉션 타입의 이해

# %% [markdown]
# ### 3주차
#
#    - Pandas 기초와 다양한 사용법

# %% [markdown]
# ### 4주차
#
#    - Numpy 기초와 사용법

# %% [markdown]
# ### 5주차
#
#    - Matplotlib을 이용한 시각화

# %% [markdown]
# ### 6주차
#
#    - Seaborn을 이용한 시각화

# %% [markdown]
# ### 7주차
#
#    - 결측치 처리와 통계량 (EDA)

# %% [markdown]
# ### 8주차
#
#    - 머신러닝 모델을 통한 예측과 상관관계 파악(선형회귀 모델)

# %% [markdown]
# ### 9주차
#
#    - 팀 단위 별 주제 선정 후 프로젝트 진행

# %%
import pandas as pd

# %%
string = ['''데이터 시각화 과정에서 흥미를 느껴서 입니다
경영정보학과를 선택했던 이유 중 하나가 졸업 후 데이터 분석 관련 직종으로 취업하고 싶었기 때문입니다. Coin학회에서 뜻이 같은 학우분들과 함께 공부하면 더욱 의미있는 시간이 될 것 같아 이전부터 눈여겨보고 있었습니다. 이번 기회에 함께하게 되어 너무 기쁩니다😊
numpy나 pandas같은 곳에서 데이터를 수집하고 분석해본적이 없는데 이런 것들을 경험해보고 싶습니다. 그리고 데이터 분석 프로젝트는 전공 수업 팀플 아니면 혼자서 하기엔 무리라고 생각합니다. 학회 coin에 가입하게 되면 데이터 관련 여러가지 프로젝트를 경험해보고 싶어서 학회에 가입하고 싶습니다.다양한 프로젝트를 진행해보고 싶습니다. 그 과정 속에서 시행착오도 겪어보며 기술적인 것 외에도 많은 것들을 배울 수 있으리라고 믿습니다!
머신 러닝에 대해서도 배워보고 싶습니다! 최근 딥페이크 기술로 인해 연예인 혹은 일반인을 대상으로 악용하는 사례가 넘쳐나 타 대학에서 딥페이크를 잡아내는 머신러닝을 개발한 것을 보았습니다. 저도 이 사례를 보고 머신 러닝에 대해 배워보고 싶다고 생각했습니다. 고3때 과외 쌤이 데이터 분석을 하셨는데, 그 모습을 보면서 데이터 분석을 대학생활 때 한번 해보고 싶었습니다!''']

# %%
string
# Out:
# ['데이터 시각화 과정에서 흥미를 느껴서 입니다\n경영정보학과를 선택했던 이유 중 하나가 졸업 후 데이터 분석 관련 직종으로 취업하고 싶었기 때문입니다. Coin학회에서 뜻이 같은 학우분들과 함께 공부하면 더욱 의미있는 시간이 될 것 같아 이전부터 눈여겨보고 있었습니다. 이번 기회에 함께하게 되어 너무 기쁩니다😊\nnumpy나 pandas같은 곳에서 데이터를 수집하고 분석해본적이 없는데 이런 것들을 경험해보고 싶습니다. 그리고 데이터 분석 프로젝트는 전공 수업 팀플 아니면 혼자서 하기엔 무리라고 생각합니다. 학회 coin에 가입하게 되면 데이터 관련 여러가지 프로젝트를 경험해보고 싶어서 학회에 가입하고 싶습니다.다양한 프로젝트를 진행해보고 싶습니다. 그 과정 속에서 시행착오도 겪어보며 기술적인 것 외에도 많은 것들을 배울 수 있으리라고 믿습니다!\n머신 러닝에 대해서도 배워보고 싶습니다! 최근 딥페이크 기술로 인해 연예인 혹은 일반인을 대상으로 악용하는 사례가 넘쳐나 타 대학에서 딥페이크를 잡아내는 머신러닝을 개발한 것을 보았습니다. 저도 이 사례를 보고 머신 러닝에 대해 배워보고 싶다고 생각했습니다. 고3때 과외 쌤이 데이터 분석을 하셨는데, 그 모습을 보면서 데이터 분석을 대학생활 때 한번 해보고 싶었습니다!']

# %%
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt
import numpy as np

okt = Okt()

# %%
sentences_tag = []

for sentence in string:
    morph = okt.pos(sentence)
    sentences_tag.append(morph)

# %%
sentences_tag
# Out:
# [[('데이터', 'Noun'),
#   ('시각', 'Noun'),
#   ('화', 'Suffix'),
#   ('과정', 'Noun'),
#   ('에서', 'Josa'),
#   ('흥미', 'Noun'),
#   ('를', 'Josa'),
#   ('느껴서', 'Verb'),
#   ('입니다', 'Adjective'),
#   ('\n', 'Foreign'),
#   ('경영정보학', 'Noun'),
#   ('과를', 'Josa'),
#   ('선택', 'Noun'),
#   ('했던', 'Verb'),
#   ('이유', 'Noun'),
#   ('중', 'Noun'),
#   ('하나', 'Noun'),
#   ('가', 'Josa'),
#   ('졸업', 'Noun'),
#   ('후', 'Noun'),
#   ('데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('관련', 'Noun'),
#   ('직종', 'Noun'),
#   ('으로', 'Josa'),
#   ('취업', 'Noun'),
#   ('하고', 'Josa'),
#   ('싶었기', 'Verb'),
#   ('때문', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('Coin', 'Alpha'),
#   ('학회', 'Noun'),
#   ('에서', 'Josa'),
#   ('뜻', 'Noun'),
#   ('이', 'Josa'),
#   ('같은', 'Adjective'),
#   ('학우', 'Noun'),
#   ('분들', 'Suffix'),
#   ('과', 'Josa'),
#   ('함께', 'Adverb'),
#   ('공부', 'Noun'),
#   ('하면', 'Verb'),
#   ('더욱', 'Noun'),
#   ('의미', 'Noun'),
#   ('있는', 'Adjective'),
#   ('시간', 'Noun'),
#   ('이', 'Josa'),
# ...

# %%
# 명사, 동사, 형용사 사용

noun_list = []
for sentence in sentences_tag:
    for word, tag in sentence:
        if tag in ["Noun","Verb", "Adjective"]:
            noun_list.append(word)

# %%
len(noun_list)

noun_list = [n for n in noun_list if len(n) > 1]
noun_list[:100]
# Out:
# ['데이터',
#  '시각',
#  '과정',
#  '흥미',
#  '느껴서',
#  '입니다',
#  '경영정보학',
#  '선택',
#  '했던',
#  '이유',
#  '하나',
#  '졸업',
#  '데이터',
#  '분석',
#  '관련',
#  '직종',
#  '취업',
#  '싶었기',
#  '때문',
#  '입니다',
#  '학회',
#  '같은',
#  '학우',
#  '공부',
#  '하면',
#  '더욱',
#  '의미',
#  '있는',
#  '시간',
#  '같아',
#  '이전',
#  '여겨',
#  '보고',
#  '있었습니다',
#  '이번',
#  '기회',
#  '하게',
#  '되어',
#  '기쁩니다',
#  '같은',
#  '데이터',
#  '수집',
#  '분석',
#  '해본',
#  '없는데',
#  '이런',
#  '경험',
#  '해보고',
#  '싶습니다',
#  '데이터',
#  '분석',
#  '프로젝트',
#  '전공',
#  '수업',
#  '아니면',
#  '혼자',
#  '하기엔',
#  '무리',
#  '생각',
#  '합니다',
#  '학회',
#  '가입',
#  '하게',
#  '되면',
#  '데이터',
#  '관련',
#  '여러가지',
#  '프로젝트',
#  '경험',
#  '해보고',
#  '싶어서',
#  '학회',
#  '가입',
#  '싶습니다',
#  '다양한',
#  '프로젝트',
#  '진행',
#  '해보고',
#  '싶습니다',
#  '과정',
#  '시행착오',
#  '겪어',
#  '보며',
#  '기술',
#  '많은',
#  '배울',
#  '있으',
#  '리라',
#  '믿습니다',
#  '머신',
#  '러닝',
#  '대해',
#  '서도',
#  '배워',
#  '보고',
#  '싶습니다',
#  '최근',
#  '페이크',
#  '기술',
#  '인해']

# %%
from collections import Counter
from wordcloud import WordCloud

# %%
counts = Counter(noun_list)
tags = counts
tags
# Out:
# Counter({'데이터': 7,
#          '시각': 1,
#          '과정': 2,
#          '흥미': 1,
#          '느껴서': 1,
#          '입니다': 2,
#          '경영정보학': 1,
#          '선택': 1,
#          '했던': 1,
#          '이유': 1,
#          '하나': 1,
#          '졸업': 1,
#          '분석': 5,
#          '관련': 2,
#          '직종': 1,
#          '취업': 1,
#          '싶었기': 1,
#          '때문': 1,
#          '학회': 3,
#          '같은': 2,
#          '학우': 1,
#          '공부': 1,
#          '하면': 1,
#          '더욱': 1,
#          '의미': 1,
#          '있는': 1,
#          '시간': 1,
#          '같아': 1,
#          '이전': 1,
#          '여겨': 1,
#          '보고': 4,
#          '있었습니다': 1,
#          '이번': 1,
#          '기회': 1,
#          '하게': 2,
#          '되어': 1,
#          '기쁩니다': 1,
#          '수집': 1,
#          '해본': 1,
#          '없는데': 1,
#          '이런': 1,
#          '경험': 2,
#          '해보고': 4,
#          '싶습니다': 4,
#          '프로젝트': 3,
#          '전공': 1,
#          '수업': 1,
#          '아니면': 1,
#          '혼자': 1,
# ...

# %%
from collections import Counter
from wordcloud import WordCloud

wordcloud = WordCloud(font_path="C:/Users/Kim/Downloads/BMEULJIROTTF.ttf",
                     background_color='white',width=800, height=600,
                     max_words=100, # word의 최대 갯수와 마스크, font-size설정
                     max_font_size=100, colormap='PuBu')
print(dict(tags))

cloud = wordcloud.generate_from_frequencies(dict(tags))
plt.figure(figsize=(12,12))
plt.axis('off')
plt.imshow(cloud, interpolation='bilinear') # 마스크용 이미지의 색으로 워드클라우드 생성
plt.show()
# Out:
# {'데이터': 7, '시각': 1, '과정': 2, '흥미': 1, '느껴서': 1, '입니다': 2, '경영정보학': 1, '선택': 1, '했던': 1, '이유': 1, '하나': 1, '졸업': 1, '분석': 5, '관련': 2, '직종': 1, '취업': 1, '싶었기': 1, '때문': 1, '학회': 3, '같은': 2, '학우': 1, '공부': 1, '하면': 1, '더욱': 1, '의미': 1, '있는': 1, '시간': 1, '같아': 1, '이전': 1, '여겨': 1, '보고': 4, '있었습니다': 1, '이번': 1, '기회': 1, '하게': 2, '되어': 1, '기쁩니다': 1, '수집': 1, '해본': 1, '없는데': 1, '이런': 1, '경험': 2, '해보고': 4, '싶습니다': 4, '프로젝트': 3, '전공': 1, '수업': 1, '아니면': 1, '혼자': 1, '하기엔': 1, '무리': 1, '생각': 2, '합니다': 1, '가입': 2, '되면': 1, '여러가지': 1, '싶어서': 1, '다양한': 1, '진행': 1, '시행착오': 1, '겪어': 1, '보며': 1, '기술': 2, '많은': 1, '배울': 1, '있으': 1, '리라': 1, '믿습니다': 1, '머신': 3, '러닝': 3, '대해': 2, '서도': 1, '배워': 2, '최근': 1, '페이크': 2, '인해': 1, '연예인': 1, '일반인': 1, '대상': 1, '악용': 1, '하는': 1, '사례': 2, '넘쳐나': 1, '대학': 2, '잡아내는': 1, '개발': 1, '보았습니다': 1, '싶다고': 1, '했습니다': 1, '과외': 1, '하셨는데': 1, '모습': 1, '보면서': 1, '생활': 1, '한번': 1, '싶었습니다': 1}

# %% [markdown]
# ## 머신러닝과 데이터 사이언스 이해

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------

# %% [markdown]
# # 데이터분석 경험해보기

# %% [markdown]
# ## 캘리포니아 집값 예측하기

# %%
# 예제 코드

#  필요 라이브러리 import 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import sklearn.linear_model # 선형회귀 모델 패키지

import warnings
warnings.filterwarnings('ignore')
plt.rc('font', family='Malgun Gothic')

# %%
housing = pd.read_csv("../data/housing.csv")

# %% [markdown]
# ### 데이터 살펴보기

# %%
# info() 메소드
# 각 열의 특성의 요약된 통계
# total_bedrooms 컬럼만 7개의 빈 값이 존재
# ocean_proximity 특성은 범주형 데이터임을 확인

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20640 non-null  int64
#  1   longitude           20640 non-null  float64
#  2   latitude            20640 non-null  float64
#  3   housing_median_age  20640 non-null  float64
#  4   total_rooms         20640 non-null  float64
#  5   total_bedrooms      20433 non-null  float64
#  6   population          20640 non-null  float64
#  7   households          20640 non-null  float64
#  8   median_income       20640 non-null  float64
#  9   median_house_value  20640 non-null  float64
#  10  ocean_proximity     20640 non-null  object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# value_counts() 
# 해당 범주형 데이터에 어떤 값이 있고 몇개의 샘플이 포함되어 있는지를 확인 가능

housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# 대부분 수치형 데이터이기 때문에 히스토그램을 그려보면 데이터를 이해하는데 도움울 줄 수 있다.

# %matplotlib inline
import matplotlib.pyplot as plt

# bins=50은 구간을 50개로 나누겠다는 파라미터

housing.hist(bins=50, figsize=(20,15))
plt.show()

# 주택 중간 연식을 보면 끝 부분이 길게 올라가고 주택 중간 값 역시 끝의 값이 높게 올라간 것을 보임
# 이렇게 자연스럽지 못한 이유는 구간이 부족해서 끝의 값 이상의 샘플들이 모두 몰린것

# 주택 중갑값의 경우 타겟값인데 만약 타겟값이 50만에 한정되어있다면 모델이 50만 이상의 값을 예측할 수 없다.
# 이런 문제의 경우 해당 데이터를 아예 제외하고 모델을 만들거나 50만을 넘어서는 추가적인 데이터를 수집하는 방법이 있다.

# 그래프가 대체적으로 왼쪽에 치우쳐진 모양
# 이를 표준형에 가깝게 변환하는 방법 이후 다룰 예정

# 데이터의 스케일이 다르다.
# households-천단위, latitude-10단위, median-house-balue 10만단위, longitude 음수 존재
# 추후 문제될 수 있음 스케일 조정도 필요

# %% [markdown]
# ### 시각화를 통한 인사이트 얻기

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", title="better_visualization_plot", alpha=0.1)

# %%
housing.plot(kind="scatter", x="latitude", y="longitude", alpha=0.4,
            s=housing["population"]/100,
            label="population",
            figsize=(10,7),
            c="median_house_value",
            cmap=plt.get_cmap("jet"),
            colorbar=True,
            sharex=False)
plt.legend()

# %%
import os
import tarfile
import urllib.request

# 그림을 저장할 위치
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/rickiepark/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

# %%
# 실제 지도와 비교

images_path = os.path.join(PROJECT_ROOT_DIR, "images", "end_to_end_project")
os.makedirs(images_path, exist_ok=True)
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
filename = "california.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/end_to_end_project/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))
# Out:
# ...
# ('.\\images\\end_to_end_project\\california.png',
#  <http.client.HTTPMessage at 0x1eec0a046c8>)

# %%
import matplotlib.image as mpimg

california_img=mpimg.imread(os.path.join(images_path, filename))
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                       s=housing['population']/100, label="Population",
                       c="median_house_value", cmap=plt.get_cmap("jet"),
                       colorbar=False, alpha=0.4,
                      )

# 이미지 덧씌우기
# [horizontal_min,horizontal_max,vertical_min,vertical_max]
# extent=[longitude_top_left,longitude_top_right,latitude_bottom_left,latitude_top_left]

plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values/prices.max())

# 컬러바 숫자 조정
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# 그래프를 보면 주택 가격은 인구밀도에 관련이 매우 크다는 사실을 알 수 있습니다.
#
# 군집 알고리즘을 사용해 주요 군집을 찾고 군집의 중심까지의 거리를 재는 특성을 추가할 수 있습니다.
#
# 해안 근접성 특성이 유용할수도 있지만, 북부 캘리포니아 지역의 해안가는 주택 가격이 그리 높지 않아 간단한 규칙이 적용되기 어렵습니다.

# %% [markdown]
# ## 특성 간 상관관계 파악

# %% [markdown]
# 각 특성간 상관관계 파악을 위해 상관계수 행렬을 얻는 것입니다. 판다스는 기본적으로 상관계수 행렬을 얻는 corr 메소드를 제공합니다.

# %%
corr_matrix = housing.corr()

# %%
# 타겟값을 기준으로 관계가 높은 다른 특성들을 정렬해서 내림차순으로 나열해봅시다.

corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# Unnamed: 0            0.072086
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %% [markdown]
# 상관관계의 범위는 -1부터 1까지 입니다. 1에 가까우면 강한 양의 상관관계를 가진다는 뜻입니다.

# %% [markdown]
# ## 산점도 행렬

# %%
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms",
             "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE9FFE6C08>,
# ...
#       dtype=object)

# %% [markdown]
# 대각선 방향(왼쪽 위에서 오른쪽 아래)은 각 변수 자신에 대한 것이라 그냥 직선이 되므로 판다스는 이곳에 히스토그램을 그립니다.
#
# 중간 주택 가격을 예측하는 데 가장 유용할 것 같은 특성은 중간 소득이므로 상관관계 산점도를 확대해보겠습니다.

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value", alpha=0.1)
plt.axis([0, 16, 0, 550000])
# Out:
# [0, 16, 0, 550000]

# %% [markdown]
# 해당 데이터의 MAX치가 50만으로 고정되어 50만 이상의 데이터는 50만으로 보여집니다.
#
# 이 부분에도 적절한 조치를 취해서 모델을 학습해야 할 가능성이 있습니다.

# %% [markdown]
# ### 변수간 상관관계 히트맵 시각화

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})

# %% [markdown]
# # 머신러닝 모델 생성 (선형회귀)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# fillna 메소드를 통해 널값은 median값으로 채워넣기

median = housing["total_bedrooms"].median()
housing["total_bedrooms"].fillna(median, inplace=True)  # 옵션 3

# %%
housing.columns
# Out:
# Index(['Unnamed: 0', 'longitude', 'latitude', 'housing_median_age',
#        'total_rooms', 'total_bedrooms', 'population', 'households',
#        'median_income', 'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
X = housing[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income']]
Y = housing['median_house_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state = 45)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict = mlr.predict(x[:100])

# %%
samples = y[:100].values

# %% [markdown]
# ## 정확도 비교

# %%
plt.figure(figsize=(12,8))
plt.plot(predict, label="predict value")

plt.plot(samples, label="real value")
plt.legend()

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
forest_reg.fit(X, Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error

housing_predictions = forest_reg.predict(X)
forest_mse = mean_squared_error(Y, housing_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse # 평균 제곱급 편차
# Out:
# 18105.713061284296

# %%
predict = forest_reg.predict(x[:100])

# %% [markdown]
# #  RandomForest

# %%
plt.figure(figsize=(12,8))
plt.plot(predict, label="predict value")

plt.plot(samples, label="real value")
plt.legend()

# %% [markdown]
# # MIS 데이터 분석의 방향(로드맵)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 위 산점도는 무슨 데이터일까요?

# %% [markdown]
# 위 그래프는 `스타크래프트 카메라 이동 정보`에 대한 산점도를 나타냅니다. 이렇듯 데이터 분석에는 도메인 지식이 굉장히 중요한 요소이고 도메인 지식이 풍부할수록 같은 데이터를 가지고도 세울 수 있는 가설이나 얻을 수 있는 인사이트가 다양해집니다.
#
# MIS의 도메인에 해당하는 산업분야는 무엇이 있을까요?
#
# - ERP(MM, SCM, CO, FI 등등)
# - BI 업무 (데이터 시각화)
# - 관심 산업분야(금융, 마케팅)

# %% [markdown]
# # 나는 어떤 성향을 가지고 있는가?

# %% [markdown]
# ![image.png](attachment:image.png)
